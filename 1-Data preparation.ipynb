# %% [markdown]
# # 1-Data preparation

# %% [markdown]
# # mental data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# เปิดไฟล์
import pandas as pd
mental_data = pd.read_excel('/content/drive/MyDrive/ColabNotebooks/Thai Mental/Y66_กรมสุขภาพจิต กระทรวงสาธารณสุข.xlsx')
mental_data.head()
# Out:
#    ที่           จังหวัด โรคสมองเสื่อม ติดแอลกอฮอล์ ติดยาบ้า (Amphetamine)  \
# 0     1    กรุงเทพมหานคร        4,495        3,006                  2,601
# 1     2      สมุทรปราการ        1,249        1,545                  1,235
# 2     3          นนทบุรี        1,581          925                    651
# 3     4         ปทุมธานี          746          694                    594
# 4     5  พระนครศรีอยุธยา          783        1,570                  2,965
#
#   ติดสารเสพติดอื่นๆ โรคจิตเภท โรคจิตอื่นๆ โรคอารมณ์สองขั้ว โรคชึมเศร้า  ...  \
# 0            4,200    15,415       3,490            3,545      17,040   ...
# 1            1,576     4,884       1,327              719       6,786   ...
# 2            1,446     4,127         970            1,532       7,373   ...
# 3            1,666     3,293         826              677       4,459   ...
# 4            2,440     3,073       1,502              641       5,160   ...
#
# ...

# %% [markdown]
# ## ลบ columns no. ทิ้ง

# %%
# ลบ columns no. ทิ้ง

# mental_data = mental_data.drop(columns='no.')
mental_data = mental_data.drop(mental_data.columns[0],axis = 1)

# %%
# แสดงข้อมูล
mental_data
# Out:
#             จังหวัด โรคสมองเสื่อม ติดแอลกอฮอล์ ติดยาบ้า (Amphetamine)  \
# 0     กรุงเทพมหานคร        4,495        3,006                  2,601
# 1       สมุทรปราการ        1,249        1,545                  1,235
# 2           นนทบุรี        1,581          925                    651
# 3          ปทุมธานี          746          694                    594
# 4   พระนครศรีอยุธยา          783        1,570                  2,965
# ..              ...           ...          ...                    ...
# 74          ปัตตานี          353          409                    632
# 75             ยะลา          270          279                    494
# 76         นราธิวาส          259          226                    659
# 77          ไม่ทราบ        1,075        3,816                  2,475
# 78             รวม        71,445      185,163                173,117
#
#    ติดสารเสพติดอื่นๆ โรคจิตเภท โรคจิตอื่นๆ โรคอารมณ์สองขั้ว โรคชึมเศร้า  \
# ...

# %% [markdown]
# ## เปลี่ยนชื่อจังหวัดจากภาษาไทยเป็นภาษาอังกฤษ

# %%
# เปลี่ยนชื่อจังหวัดจากภาษาไทยเป็นภาษาอังกฤษ
mental_data = mental_data.replace({"จังหวัด": {"กรุงเทพมหานคร": "Bangkok Metropolis",
                                     "สมุทรปราการ": "Samut Prakan",
                                     "นนทบุรี": "Nonthaburi",
                                     "ปทุมธานี": "Pathum Thani",
                                     "พระนครศรีอยุธยา": "Phra Nakhon Si Ayutthaya",
                                     "อ่างทอง": "Ang Thong",
                                     "ลพบุรี": "Lop Buri",
                                     "สิงห์บุรี": "Sing Buri",
                                     "ชัยนาท": "Chai Nat",
                                     "สระบุรี": "Saraburi",
                                     "ชลบุรี": "Chon Buri",
                                     "ระยอง": "Rayong",
                                     "จันทบุรี": "Chanthaburi",
                                     "ตราด": "Trat",
                                     "ฉะเชิงเทรา": "Chachoengsao",
                                     "ปราจีนบุรี": "Prachin Buri",
                                     "นครนายก": "Nakhon Nayok",
                                     "สระแก้ว": "Sa Kaeo",
                                     "นครราชสีมา": "Nakhon Ratchasima",
                                     "บุรีรัมย์": "Buri Ram",
                                     "สุรินทร์": "Surin",
                                     "ศรีสะเกษ": "Si Sa Ket",
                                     "อุบลราชธานี": "Ubon Ratchathani",
                                     "ยโสธร": "Yasothon",
                                     "ชัยภูมิ": "Chaiyaphum",
                                     "อำนาจเจริญ": "Amnat Charoen",
                                     "บึงกาฬ": "Bueng Kan",
                                     "หนองบัวลำภู": "Nong Bua Lam Phu",
                                     "ขอนแก่น": "Khon Kaen",
                                     "อุดรธานี": "Udon Thani",
                                     "เลย": "Loei",
                                     "หนองคาย": "Nong Khai",
                                     "มหาสารคาม": "Maha Sarakham",
                                     "ร้อยเอ็ด": "Roi Et",
                                     "กาฬสินธุ์": "Kalasin",
                                     "สกลนคร": "Sakon Nakhon",
                                     "นครพนม": "Nakhon Phanom",
                                     "มุกดาหาร": "Mukdahan",
                                     "เชียงใหม่": "Chiang Mai",
                                     "ลำพูน": "Lamphun",
                                     "ลำปาง": "Lampang",
                                     "อุตรดิตถ์": "Uttaradit",
                                     "แพร่": "Phrae",
                                     "น่าน": "Nan",
                                     "พะเยา": "Phayao",
                                     "เชียงราย": "Chiang Rai",
                                     "แม่ฮ่องสอน": "Mae Hong Son",
                                     "นครสวรรค์": "Nakhon Sawan",
                                     "อุทัยธานี": "Uthai Thani",
                                     "กำแพงเพชร": "Kamphaeng Phet",
                                     "ตาก": "Tak",
                                     "สุโขทัย": "Sukhothai",
                                     "พิษณุโลก": "Phitsanulok",
                                     "พิจิตร": "Phichit",
                                     "เพชรบูรณ์": "Phetchabun",
                                     "ราชบุรี": "Ratchaburi",
                                     "กาญจนบุรี": "Kanchanaburi",
                                     "สุพรรณบุรี": "Suphan Buri",
                                     "นครปฐม": "Nakhon Pathom",
                                     "สมุทรสาคร": "Samut Sakhon",
                                     "สมุทรสงคราม": "Samut Songkhram",
                                     "เพชรบุรี": "Phetchaburi",
                                     "ประจวบคีรีขันธ์": "Prachuap Khiri Khan",
                                     "นครศรีธรรมราช": "Nakhon Si Thammarat",
                                     "กระบี่": "Krabi",
                                     "พังงา": "Phangnga",
                                     "ภูเก็ต": "Phuket",
                                     "สุราษฎร์ธานี": "Surat Thani",
                                     "ระนอง": "Ranong",
                                     "ชุมพร": "Chumphon",
                                     "สงขลา": "Songkhla",
                                     "สตูล": "Satun",
                                     "ตรัง": "Trang",
                                     "พัทลุง": "Phatthalung",
                                     "ปัตตานี": "Pattani",
                                     "ยะลา": "Yala",
                                     "นราธิวาส": "Narathiwat"
                                    }})

# %% [markdown]
# ## ลบ columns "รวม" ทิ้ง

# %%
# ลบ columns รวม ทิ้ง
mental_data = mental_data.drop(columns='รวม')

# %%
# แสดงข้อมูล
mental_data
# Out:
#                      จังหวัด โรคสมองเสื่อม ติดแอลกอฮอล์  \
# 0         Bangkok Metropolis        4,495        3,006
# 1               Samut Prakan        1,249        1,545
# 2                 Nonthaburi        1,581          925
# 3               Pathum Thani          746          694
# 4   Phra Nakhon Si Ayutthaya          783        1,570
# ..                       ...           ...          ...
# 74                   Pattani          353          409
# 75                      Yala          270          279
# 76                Narathiwat          259          226
# 77                   ไม่ทราบ        1,075        3,816
# 78                      รวม        71,445      185,163
#
#    ติดยาบ้า (Amphetamine) ติดสารเสพติดอื่นๆ โรคจิตเภท โรคจิตอื่นๆ  \
# 0                  2,601             4,200    15,415       3,490
# 1                  1,235             1,576     4,884       1,327
# 2                    651             1,446     4,127         970
# ...

# %% [markdown]
# ## ลบ row แถวที่ index 77, 78 ซึ่งคือ ไม่ทราบ และรวม ทิ้ง

# %%
## ลบ row แถวที่ index 77, 78 ซึ่งคือ ไม่ทราบ และรวม ทิ้ง
mental_data = mental_data.drop(index=[77,78])
# mental_data = mental_data.drop(index=[77])

# %%
# แสดงข้อมูล
mental_data
# Out:
#                      จังหวัด โรคสมองเสื่อม ติดแอลกอฮอล์  \
# 0         Bangkok Metropolis        4,495        3,006
# 1               Samut Prakan        1,249        1,545
# 2                 Nonthaburi        1,581          925
# 3               Pathum Thani          746          694
# 4   Phra Nakhon Si Ayutthaya          783        1,570
# ..                       ...           ...          ...
# 72                     Trang          538        1,303
# 73               Phatthalung          585          645
# 74                   Pattani          353          409
# 75                      Yala          270          279
# 76                Narathiwat          259          226
#
#    ติดยาบ้า (Amphetamine) ติดสารเสพติดอื่นๆ โรคจิตเภท โรคจิตอื่นๆ  \
# 0                  2,601             4,200    15,415       3,490
# 1                  1,235             1,576     4,884       1,327
# 2                    651             1,446     4,127         970
# ...

# %% [markdown]
# ## เปลี่ยนชื่อ columns จากภาษาไทยเป็นภาษาอังกฤษ

# %%
# เปลี่ยนชื่อ columns จากภาษาไทยเป็นภาษาอังกฤษ
mental_data = mental_data.rename(columns={"จังหวัด": "Province",
                                                 "โรคสมองเสื่อม":"Dementia",
                                                  "ติดแอลกอฮอล์":"Alcoholic",
                                                  "ติดยาบ้า (Amphetamine)":"Addicted to Amphetamine",
                                                  "ติดสารเสพติดอื่นๆ":"Addicted to other drugs",
                                                  "โรคจิตเภท":"Schizophrenia",
                                                  "โรคจิตอื่นๆ":"Other Mental Illnesses",
                                                  "โรคอารมณ์สองขั้ว":"Bipolar Disorder",
                                                  "โรคชึมเศร้า":"Depression",
                                                  "โรควิตกกังวล":"Anxiety Disorder",
                                                  "ความบกพร่องทางสติปัญญา":"Intellectual Disabilities",
                                                  "ความบกพร่องทางการเรียนรู้":"Learning Disabilities",
                                                  "โรคออทิสติก":"Autistic Disorder",
                                                  "โรคสมาธิสั้น":"ADHD",
                                                  "พยามยามฆ่าตัวตาย (การตั้งใจทำร้ายตนเอง)":"Self-Harm",
                                                  "ผู้ป่วยติดเกมส์ในผู้ใหญ่ (15 ปีขึ้นไป)":"Game Addiction(Older than 15 years old)",
                                                  "ผู้ป่วยติดเกมส์ในเด็ก (อายุต่ำกว่า 15 ปี)":"Game Addiction(Younger than 15 years old)",
                                                  "โรคทางจิตเวชอื่นๆ":"Other Psychosis",
                                                  "โรคลมชัก":"Epilepsy"
                                                 })

# %%
# แสดงข้อมูล
mental_data
# Out:
#                     Province Dementia Alcoholic Addicted to Amphetamine  \
# 0         Bangkok Metropolis   4,495     3,006                   2,601
# 1               Samut Prakan   1,249     1,545                   1,235
# 2                 Nonthaburi   1,581       925                     651
# 3               Pathum Thani     746       694                     594
# 4   Phra Nakhon Si Ayutthaya     783     1,570                   2,965
# ..                       ...      ...       ...                     ...
# 72                     Trang     538     1,303                   1,440
# 73               Phatthalung     585       645                   1,344
# 74                   Pattani     353       409                     632
# 75                      Yala     270       279                     494
# 76                Narathiwat     259       226                     659
#
#    Addicted to other drugs Schizophrenia Other Mental Illnesses  \
# ...

# %% [markdown]
# ## แก้เป็น int (เอา ',' ออก)

# %%
def thisfunction(st):
    return int(str(st).replace(',',''))

mental_data.iloc[:,1:] = mental_data.iloc[:,1:].applymap(thisfunction)

# %%
mental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Province                                   77 non-null     object
#  1   Dementia                                   77 non-null     object
#  2   Alcoholic                                  77 non-null     object
#  3   Addicted to Amphetamine                    77 non-null     object
#  4   Addicted to other drugs                    77 non-null     object
#  5   Schizophrenia                              77 non-null     object
#  6   Other Mental Illnesses                     77 non-null     object
#  7   Bipolar Disorder                           77 non-null     object
#  8   Depression                                 77 non-null     object
#  9   Anxiety Disorder                           77 non-null     object
# ...

# %%
mental_data
# Out:
#                     Province Dementia Alcoholic Addicted to Amphetamine  \
# 0         Bangkok Metropolis     4495      3006                    2601
# 1               Samut Prakan     1249      1545                    1235
# 2                 Nonthaburi     1581       925                     651
# 3               Pathum Thani      746       694                     594
# 4   Phra Nakhon Si Ayutthaya      783      1570                    2965
# ..                       ...      ...       ...                     ...
# 72                     Trang      538      1303                    1440
# 73               Phatthalung      585       645                    1344
# 74                   Pattani      353       409                     632
# 75                      Yala      270       279                     494
# 76                Narathiwat      259       226                     659
#
#    Addicted to other drugs Schizophrenia Other Mental Illnesses  \
# ...

# %% [markdown]
# ## Sort ตามชื่อ Province

# %%
## Sort ตามชื่อ Province
mental_data.sort_values(by=['Province'], inplace=True)
mental_data
# Out:
#               Province Dementia Alcoholic Addicted to Amphetamine  \
# 25       Amnat Charoen      345      1644                    1638
# 5            Ang Thong      476       988                     895
# 0   Bangkok Metropolis     4495      3006                    2601
# 26           Bueng Kan      251      1063                    2911
# 19            Buri Ram     1644      9515                    4990
# ..                 ...      ...       ...                     ...
# 29          Udon Thani     1321      4174                    5950
# 48         Uthai Thani      633      1481                    2114
# 41           Uttaradit      301       926                    1428
# 75                Yala      270       279                     494
# 23            Yasothon      410      1655                    1782
#
#    Addicted to other drugs Schizophrenia Other Mental Illnesses  \
# 25                     818          2418                   1113
# ...

# %% [markdown]
# ## save file ออกเป็น .xlsx

# %%
# save file ออกเป็น .xlsx
mental_data.to_excel('mental_y66_data_cleaned.xlsx', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # Population data

# %%
# เปิดไฟล์
import pandas as pd
population_data = pd.read_excel('/content/drive/MyDrive/ColabNotebooks/Thai Mental/population_66.xlsx')
population_data.head()
# Out:
#                   พื้นที่      ชาย     หญิง      รวม
# 0           กรุงเทพมหานคร  2561655  2915650  5477305
# 1      จังหวัดสมุทรปราการ   649055   717453  1366508
# 2          จังหวัดนนทบุรี   603583   697937  1301520
# 3         จังหวัดปทุมธานี   572655   637642  1210297
# 4  จังหวัดพระนครศรีอยุธยา   393871   427281   821152

# %% [markdown]
# ## เปลี่ยนชื่อจังหวัดจากภาษาไทยเป็นภาษาอังกฤษ

# %%
# เปลี่ยนชื่อจังหวัดจากภาษาไทยเป็นภาษาอังกฤษ
population_data_province = population_data.replace({"พื้นที่": {"กรุงเทพมหานคร": "Bangkok Metropolis",
                                     "จังหวัดสมุทรปราการ": "Samut Prakan",
                                     "จังหวัดนนทบุรี": "Nonthaburi",
                                     "จังหวัดปทุมธานี": "Pathum Thani",
                                     "จังหวัดพระนครศรีอยุธยา": "Phra Nakhon Si Ayutthaya",
                                     "จังหวัดอ่างทอง": "Ang Thong",
                                     "จังหวัดลพบุรี": "Lop Buri",
                                     "จังหวัดสิงห์บุรี": "Sing Buri",
                                     "จังหวัดชัยนาท": "Chai Nat",
                                     "จังหวัดสระบุรี": "Saraburi",
                                     "จังหวัดชลบุรี": "Chon Buri",
                                     "จังหวัดระยอง": "Rayong",
                                     "จังหวัดจันทบุรี": "Chanthaburi",
                                     "จังหวัดตราด": "Trat",
                                     "จังหวัดฉะเชิงเทรา": "Chachoengsao",
                                     "จังหวัดปราจีนบุรี": "Prachin Buri",
                                     "จังหวัดนครนายก": "Nakhon Nayok",
                                     "จังหวัดสระแก้ว": "Sa Kaeo",
                                     "จังหวัดนครราชสีมา": "Nakhon Ratchasima",
                                     "จังหวัดบุรีรัมย์": "Buri Ram",
                                     "จังหวัดสุรินทร์": "Surin",
                                     "จังหวัดศรีสะเกษ": "Si Sa Ket",
                                     "จังหวัดอุบลราชธานี": "Ubon Ratchathani",
                                     "จังหวัดยโสธร": "Yasothon",
                                     "จังหวัดชัยภูมิ": "Chaiyaphum",
                                     "จังหวัดอำนาจเจริญ": "Amnat Charoen",
                                     "จังหวัดบึงกาฬ": "Bueng Kan",
                                     "จังหวัดหนองบัวลำภู": "Nong Bua Lam Phu",
                                     "จังหวัดขอนแก่น": "Khon Kaen",
                                     "จังหวัดอุดรธานี": "Udon Thani",
                                     "จังหวัดเลย": "Loei",
                                     "จังหวัดหนองคาย": "Nong Khai",
                                     "จังหวัดมหาสารคาม": "Maha Sarakham",
                                     "จังหวัดร้อยเอ็ด": "Roi Et",
                                     "จังหวัดกาฬสินธุ์": "Kalasin",
                                     "จังหวัดสกลนคร": "Sakon Nakhon",
                                     "จังหวัดนครพนม": "Nakhon Phanom",
                                     "จังหวัดมุกดาหาร": "Mukdahan",
                                     "จังหวัดเชียงใหม่": "Chiang Mai",
                                     "จังหวัดลำพูน": "Lamphun",
                                     "จังหวัดลำปาง": "Lampang",
                                     "จังหวัดอุตรดิตถ์": "Uttaradit",
                                     "จังหวัดแพร่": "Phrae",
                                     "จังหวัดน่าน": "Nan",
                                     "จังหวัดพะเยา": "Phayao",
                                     "จังหวัดเชียงราย": "Chiang Rai",
                                     "จังหวัดแม่ฮ่องสอน": "Mae Hong Son",
                                     "จังหวัดนครสวรรค์": "Nakhon Sawan",
                                     "จังหวัดอุทัยธานี": "Uthai Thani",
                                     "จังหวัดกำแพงเพชร": "Kamphaeng Phet",
                                     "จังหวัดตาก": "Tak",
                                     "จังหวัดสุโขทัย": "Sukhothai",
                                     "จังหวัดพิษณุโลก": "Phitsanulok",
                                     "จังหวัดพิจิตร": "Phichit",
                                     "จังหวัดเพชรบูรณ์": "Phetchabun",
                                     "จังหวัดราชบุรี": "Ratchaburi",
                                     "จังหวัดกาญจนบุรี": "Kanchanaburi",
                                     "จังหวัดสุพรรณบุรี": "Suphan Buri",
                                     "จังหวัดนครปฐม": "Nakhon Pathom",
                                     "จังหวัดสมุทรสาคร": "Samut Sakhon",
                                     "จังหวัดสมุทรสงคราม": "Samut Songkhram",
                                     "จังหวัดเพชรบุรี": "Phetchaburi",
                                     "จังหวัดประจวบคีรีขันธ์": "Prachuap Khiri Khan",
                                     "จังหวัดนครศรีธรรมราช": "Nakhon Si Thammarat",
                                     "จังหวัดกระบี่": "Krabi",
                                     "จังหวัดพังงา": "Phangnga",
                                     "จังหวัดภูเก็ต": "Phuket",
                                     "จังหวัดสุราษฎร์ธานี": "Surat Thani",
                                     "จังหวัดระนอง": "Ranong",
                                     "จังหวัดชุมพร": "Chumphon",
                                     "จังหวัดสงขลา": "Songkhla",
                                     "จังหวัดสตูล": "Satun",
                                     "จังหวัดตรัง": "Trang",
                                     "จังหวัดพัทลุง": "Phatthalung",
                                     "จังหวัดปัตตานี": "Pattani",
                                     "จังหวัดยะลา": "Yala",
                                     "จังหวัดนราธิวาส": "Narathiwat"
                                    }})

# %%
population_data_province
# Out:
#                      พื้นที่      ชาย     หญิง      รวม
# 0         Bangkok Metropolis  2561655  2915650  5477305
# 1               Samut Prakan   649055   717453  1366508
# 2                 Nonthaburi   603583   697937  1301520
# 3               Pathum Thani   572655   637642  1210297
# 4   Phra Nakhon Si Ayutthaya   393871   427281   821152
# ..                       ...      ...      ...      ...
# 72                     Trang   311514   326201   637715
# 73               Phatthalung   253692   267639   521331
# 74                   Pattani   363680   371810   735490
# 75                      Yala   272420   275741   548161
# 76                Narathiwat   403939   412951   816890
#
# [77 rows x 4 columns]

# %% [markdown]
# ## เปลี่ยนชื่อ columns จากภาษาไทยเป็นภาษาอังกฤษ

# %%
# เปลี่ยนชื่อ columns จากภาษาไทยเป็นภาษาอังกฤษ
population_data = population_data_province.rename(columns={"พื้นที่": "Province",
                                                 "ชาย":"Male_population",
                                                 "หญิง":"Women_population",
                                                 "รวม":"Total_population"
                                                 })

# %%
population_data
# Out:
#                     Province  Male_population  Women_population  \
# 0         Bangkok Metropolis          2561655           2915650
# 1               Samut Prakan           649055            717453
# 2                 Nonthaburi           603583            697937
# 3               Pathum Thani           572655            637642
# 4   Phra Nakhon Si Ayutthaya           393871            427281
# ..                       ...              ...               ...
# 72                     Trang           311514            326201
# 73               Phatthalung           253692            267639
# 74                   Pattani           363680            371810
# 75                      Yala           272420            275741
# 76                Narathiwat           403939            412951
#
#     Total_population
# 0            5477305
# 1            1366508
# 2            1301520
# 3            1210297
# 4             821152
# ..               ...
# 72            637715
# ...

# %% [markdown]
# ## Sort ตามชื่อ Province

# %%
population_data = population_data.sort_values(by=['Province'])
population_data
# Out:
#               Province  Male_population  Women_population  Total_population
# 25       Amnat Charoen           186311            188595            374906
# 5            Ang Thong           129795            141616            271411
# 0   Bangkok Metropolis          2561655           2915650           5477305
# 26           Bueng Kan           210764            210403            421167
# 19            Buri Ram           780227            794792           1575019
# ..                 ...              ...               ...               ...
# 29          Udon Thani           770661            790030           1560691
# 48         Uthai Thani           157630            165329            322959
# 41           Uttaradit           214722            226522            441244
# 75                Yala           272420            275741            548161
# 23            Yasothon           264131            266387            530518
#
# [77 rows x 4 columns]

# %% [markdown]
# ## save file ออกเป็น .xlsx

# %%
# save file ออกเป็น .xlsx
population_data.to_excel('population_y66_data_cleaned.xlsx', index=False)

# %% [markdown]
# # Merge the table

# %%
# using merge function by setting how='inner'
mental_population_merge = pd.merge(mental_data, population_data,
                   on='Province',
                   how='inner')
mental_population_merge
# Out:
#               Province  Dementia  Alcoholic  Addicted to Amphetamine  \
# 0        Amnat Charoen       345       1644                     1638
# 1            Ang Thong       476        988                      895
# 2   Bangkok Metropolis      4495       3006                     2601
# 3            Bueng Kan       251       1063                     2911
# 4             Buri Ram      1644       9515                     4990
# ..                 ...       ...        ...                      ...
# 72          Udon Thani      1321       4174                     5950
# 73         Uthai Thani       633       1481                     2114
# 74           Uttaradit       301        926                     1428
# 75                Yala       270        279                      494
# 76            Yasothon       410       1655                     1782
#
#     Addicted to other drugs  Schizophrenia  Other Mental Illnesses  \
# 0                       818           2418                    1113
# ...

# %% [markdown]
# ## save file ออกเป็น .xlsx

# %%
# save file ออกเป็น .xlsx
mental_population_merge.to_excel('mental_population_merge_y66.xlsx', index=False)

# %% [markdown]
# # Calculate

# %%
mental_population_merge.iloc[:,1:] = mental_population_merge.iloc[:,1:].apply(lambda x: (x/x['Total_population'])*100000, axis=1)
# Out:
# <ipython-input-98-de654acd7974>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   mental_population_merge.iloc[:,1:] = mental_population_merge.iloc[:,1:].apply(lambda x: (x/x['Total_population'])*100000, axis=1)

# %%
mental_population_merge
# Out:
#               Province    Dementia   Alcoholic  Addicted to Amphetamine  \
# 0        Amnat Charoen   92.023067  438.509920               436.909519
# 1            Ang Thong  175.379775  364.023566               329.758190
# 2   Bangkok Metropolis   82.065906   54.881004                47.486857
# 3            Bueng Kan   59.596312  252.393943               691.174760
# 4             Buri Ram  104.379693  604.119696               316.821575
# ..                 ...         ...         ...                      ...
# 72          Udon Thani   84.641995  267.445638               381.241386
# 73         Uthai Thani  196.000111  458.572141               654.572252
# 74           Uttaradit   68.216225  209.861211               323.630463
# 75                Yala   49.255602   50.897455                90.119509
# 76            Yasothon   77.282957  311.959255               335.898122
#
#     Addicted to other drugs  Schizophrenia  Other Mental Illnesses  \
# ...

# %% [markdown]
# ## save file ออกเป็น .xlsx

# %%
# save file ออกเป็น .xlsx
mental_population_merge.to_excel('mental_y66_data_calculated.xlsx', index=False)

# %% [markdown]
# ---
